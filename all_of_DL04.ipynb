# %% [markdown]
# <a href="https://colab.research.google.com/github/monindew/all_of_DL/blob/main/all_of_DL04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
x = np.array([2, 4, 6, 8, 10, 12, 14])
y = np.array([0, 0, 0, 1, 1, 1, 1])

model = Sequential()
model.add(Dense(1, input_dim=1, activation='sigmoid'))

model.compile(optimizer='sgd', loss='binary_crossentropy')
model.fit(x, y, epochs=5000)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2598
# Epoch 2502/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2598
# Epoch 2503/5000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2597
# Epoch 2504/5000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2597
# Epoch 2505/5000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2597
# Epoch 2506/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2596
# Epoch 2507/5000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2596
# Epoch 2508/5000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2595
# Epoch 2509/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2595
# Epoch 2510/5000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2594
# Epoch 2511/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2594
# Epoch 2512/5000
# ...

# %%
plt.scatter(x, y)
plt.plot(x, model.predict(x), 'r')
plt.show()
# Out:
# 1/1 [==============================] - 0s 158ms/step

# %%
hour = 7
prediction = model.predict([hour])
print("%.f시간을 공부할 경우, 합경 예상 확률은 %.01f%%입니다." % (hour, prediction * 100))
# Out:
# 1/1 [==============================] - 0s 36ms/step
# 7시간을 공부할 경우, 합경 예상 확률은 59.7%입니다.
# <ipython-input-5-f2ebc3076eb5>:3: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("%.f시간을 공부할 경우, 합경 예상 확률은 %.01f%%입니다." % (hour, prediction * 100))
